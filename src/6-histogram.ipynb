# %% [markdown]
# ### Exercise 6: Histogram Customization

# %%
# TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Line Plot
t = np.linspace(0, 10, 100)
axes[0, 0].plot(t, t**2, label='y = x^2', color='b')
axes[0, 0].set_title('Line Plot')
axes[0, 0].set_xlabel('X values')
axes[0, 0].set_ylabel('Y values')
axes[0, 0].grid(True)
axes[0, 0].legend()

# Bar Plot
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
colors = ['red', 'blue', 'green', 'purple']
axes[0, 1].bar(categories, values, color=colors)
axes[0, 1].set_title('Bar Chart')
axes[0, 1].set_xlabel('Categories')
axes[0, 1].set_ylabel('Values')

# Scatter Plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
axes[1, 0].scatter(x, y, color='blue')
for i, j in zip(x, y):
    axes[1, 0].text(i, j, f'({i}, {j})', fontsize=10, ha='right')
axes[1, 0].set_title('Scatter Plot')
axes[1, 0].set_xlabel('X values')
axes[1, 0].set_ylabel('Y values')
axes[1, 0].grid(True)

# Pie Chart
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]
axes[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['blue', 'green', 'red', 'orange'])
axes[1, 1].set_title('Pie Chart')

# Histogram
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5]
plt.figure(figsize=(8, 5))
plt.hist(data, bins=5, color='cyan', edgecolor='black')
plt.title('Histogram of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Adjust layout and show plot
plt.tight_layout()
plt.show()
